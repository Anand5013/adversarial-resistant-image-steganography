# %% [markdown]
# ## FLOWER IMAGES

# %% [markdown]
# Composite Image Generation, Estimated Features, Global and Local Score, Stego Image

# %%
# !python main.py --phase test --dataset_dir flower --checkpoint_dir ./check/flower --test_dir ./check/flower/test --gpu 0ju
# Out:
# generator_hiding/g_e1_c/Conv/weights:0
# generator_hiding/g_e1_bn/scale:0
# generator_hiding/g_e1_bn/offset:0
# generator_hiding/g_e2_c/Conv/weights:0
# generator_hiding/g_e2_bn/scale:0
# generator_hiding/g_e2_bn/offset:0
# generator_hiding/g_e3_c/Conv/weights:0
# generator_hiding/g_e3_bn/scale:0
# generator_hiding/g_e3_bn/offset:0
# generator_hiding/g_r1_c1/Conv/weights:0
# generator_hiding/g_r1_bn1/scale:0
# generator_hiding/g_r1_bn1/offset:0
# generator_hiding/g_r1_c2/Conv/weights:0
# generator_hiding/g_r1_bn2/scale:0
# generator_hiding/g_r1_bn2/offset:0
# generator_hiding/g_r2_c1/Conv/weights:0
# generator_hiding/g_r2_bn1/scale:0
# generator_hiding/g_r2_bn1/offset:0
# generator_hiding/g_r2_c2/Conv/weights:0
# generator_hiding/g_r2_bn2/scale:0
# generator_hiding/g_r2_bn2/offset:0
# generator_hiding/g_r3_c1/Conv/weights:0
# generator_hiding/g_r3_bn1/scale:0
# generator_hiding/g_r3_bn1/offset:0
# generator_hiding/g_r3_c2/Conv/weights:0
# generator_hiding/g_r3_bn2/scale:0
# ...

# %% [markdown]
# Reconstructed Cover and Secret Image

# %%
# !python main.py --phase recon --stegano_dir ./check/flower/test/stego --recon_dir ./check/flower/recon --gpu 0 --checkpoint_dir ./check/flower
# Out:
# generator_hiding/g_e1_c/Conv/weights:0
# generator_hiding/g_e1_bn/scale:0
# generator_hiding/g_e1_bn/offset:0
# generator_hiding/g_e2_c/Conv/weights:0
# generator_hiding/g_e2_bn/scale:0
# generator_hiding/g_e2_bn/offset:0
# generator_hiding/g_e3_c/Conv/weights:0
# generator_hiding/g_e3_bn/scale:0
# generator_hiding/g_e3_bn/offset:0
# generator_hiding/g_r1_c1/Conv/weights:0
# generator_hiding/g_r1_bn1/scale:0
# generator_hiding/g_r1_bn1/offset:0
# generator_hiding/g_r1_c2/Conv/weights:0
# generator_hiding/g_r1_bn2/scale:0
# generator_hiding/g_r1_bn2/offset:0
# generator_hiding/g_r2_c1/Conv/weights:0
# generator_hiding/g_r2_bn1/scale:0
# generator_hiding/g_r2_bn1/offset:0
# generator_hiding/g_r2_c2/Conv/weights:0
# generator_hiding/g_r2_bn2/scale:0
# generator_hiding/g_r2_bn2/offset:0
# generator_hiding/g_r3_c1/Conv/weights:0
# generator_hiding/g_r3_bn1/scale:0
# generator_hiding/g_r3_bn1/offset:0
# generator_hiding/g_r3_c2/Conv/weights:0
# generator_hiding/g_r3_bn2/scale:0
# ...

# %% [markdown]
# ## Caricature Image

# %%
# !python main.py --phase test --dataset_dir cari --checkpoint_dir ./check/flower --test_dir ./sample/cari --gpu 0
# Out:
# generator_hiding/g_e1_c/Conv/weights:0
# generator_hiding/g_e1_bn/scale:0
# generator_hiding/g_e1_bn/offset:0
# generator_hiding/g_e2_c/Conv/weights:0
# generator_hiding/g_e2_bn/scale:0
# generator_hiding/g_e2_bn/offset:0
# generator_hiding/g_e3_c/Conv/weights:0
# generator_hiding/g_e3_bn/scale:0
# generator_hiding/g_e3_bn/offset:0
# generator_hiding/g_r1_c1/Conv/weights:0
# generator_hiding/g_r1_bn1/scale:0
# generator_hiding/g_r1_bn1/offset:0
# generator_hiding/g_r1_c2/Conv/weights:0
# generator_hiding/g_r1_bn2/scale:0
# generator_hiding/g_r1_bn2/offset:0
# generator_hiding/g_r2_c1/Conv/weights:0
# generator_hiding/g_r2_bn1/scale:0
# generator_hiding/g_r2_bn1/offset:0
# generator_hiding/g_r2_c2/Conv/weights:0
# generator_hiding/g_r2_bn2/scale:0
# generator_hiding/g_r2_bn2/offset:0
# generator_hiding/g_r3_c1/Conv/weights:0
# generator_hiding/g_r3_bn1/scale:0
# generator_hiding/g_r3_bn1/offset:0
# generator_hiding/g_r3_c2/Conv/weights:0
# generator_hiding/g_r3_bn2/scale:0
# ...

# %%
# !python main.py --phase recon --stegano_dir ./sample/cari/stego --recon_dir ./recon/cari --gpu 0 --checkpoint_dir ./check/flower
# Out:
# generator_hiding/g_e1_c/Conv/weights:0
# generator_hiding/g_e1_bn/scale:0
# generator_hiding/g_e1_bn/offset:0
# generator_hiding/g_e2_c/Conv/weights:0
# generator_hiding/g_e2_bn/scale:0
# generator_hiding/g_e2_bn/offset:0
# generator_hiding/g_e3_c/Conv/weights:0
# generator_hiding/g_e3_bn/scale:0
# generator_hiding/g_e3_bn/offset:0
# generator_hiding/g_r1_c1/Conv/weights:0
# generator_hiding/g_r1_bn1/scale:0
# generator_hiding/g_r1_bn1/offset:0
# generator_hiding/g_r1_c2/Conv/weights:0
# generator_hiding/g_r1_bn2/scale:0
# generator_hiding/g_r1_bn2/offset:0
# generator_hiding/g_r2_c1/Conv/weights:0
# generator_hiding/g_r2_bn1/scale:0
# generator_hiding/g_r2_bn1/offset:0
# generator_hiding/g_r2_c2/Conv/weights:0
# generator_hiding/g_r2_bn2/scale:0
# generator_hiding/g_r2_bn2/offset:0
# generator_hiding/g_r3_c1/Conv/weights:0
# generator_hiding/g_r3_bn1/scale:0
# generator_hiding/g_r3_bn1/offset:0
# generator_hiding/g_r3_c2/Conv/weights:0
# generator_hiding/g_r3_bn2/scale:0
# ...

# %% [markdown]
# ## Vehicle Image

# %%
# !python main.py --phase test --dataset_dir vehicle --checkpoint_dir ./check/flower --test_dir ./sample/vehicle --gpu 0
# Out:
# generator_hiding/g_e1_c/Conv/weights:0
# generator_hiding/g_e1_bn/scale:0
# generator_hiding/g_e1_bn/offset:0
# generator_hiding/g_e2_c/Conv/weights:0
# generator_hiding/g_e2_bn/scale:0
# generator_hiding/g_e2_bn/offset:0
# generator_hiding/g_e3_c/Conv/weights:0
# generator_hiding/g_e3_bn/scale:0
# generator_hiding/g_e3_bn/offset:0
# generator_hiding/g_r1_c1/Conv/weights:0
# generator_hiding/g_r1_bn1/scale:0
# generator_hiding/g_r1_bn1/offset:0
# generator_hiding/g_r1_c2/Conv/weights:0
# generator_hiding/g_r1_bn2/scale:0
# generator_hiding/g_r1_bn2/offset:0
# generator_hiding/g_r2_c1/Conv/weights:0
# generator_hiding/g_r2_bn1/scale:0
# generator_hiding/g_r2_bn1/offset:0
# generator_hiding/g_r2_c2/Conv/weights:0
# generator_hiding/g_r2_bn2/scale:0
# generator_hiding/g_r2_bn2/offset:0
# generator_hiding/g_r3_c1/Conv/weights:0
# generator_hiding/g_r3_bn1/scale:0
# generator_hiding/g_r3_bn1/offset:0
# generator_hiding/g_r3_c2/Conv/weights:0
# generator_hiding/g_r3_bn2/scale:0
# ...

# %%
# !python main.py --phase recon --stegano_dir ./sample/vehicle/stego --recon_dir ./recon/vehicle --gpu 0 --checkpoint_dir ./check/flower
# Out:
# generator_hiding/g_e1_c/Conv/weights:0
# generator_hiding/g_e1_bn/scale:0
# generator_hiding/g_e1_bn/offset:0
# generator_hiding/g_e2_c/Conv/weights:0
# generator_hiding/g_e2_bn/scale:0
# generator_hiding/g_e2_bn/offset:0
# generator_hiding/g_e3_c/Conv/weights:0
# generator_hiding/g_e3_bn/scale:0
# generator_hiding/g_e3_bn/offset:0
# generator_hiding/g_r1_c1/Conv/weights:0
# generator_hiding/g_r1_bn1/scale:0
# generator_hiding/g_r1_bn1/offset:0
# generator_hiding/g_r1_c2/Conv/weights:0
# generator_hiding/g_r1_bn2/scale:0
# generator_hiding/g_r1_bn2/offset:0
# generator_hiding/g_r2_c1/Conv/weights:0
# generator_hiding/g_r2_bn1/scale:0
# generator_hiding/g_r2_bn1/offset:0
# generator_hiding/g_r2_c2/Conv/weights:0
# generator_hiding/g_r2_bn2/scale:0
# generator_hiding/g_r2_bn2/offset:0
# generator_hiding/g_r3_c1/Conv/weights:0
# generator_hiding/g_r3_bn1/scale:0
# generator_hiding/g_r3_bn1/offset:0
# generator_hiding/g_r3_c2/Conv/weights:0
# generator_hiding/g_r3_bn2/scale:0
# ...

# %% [markdown]
# ## Sample Cover & Secret Image

# %%
# !python main.py --phase test --dataset_dir test --checkpoint_dir ./check/flower --test_dir ./final --gpu 0
# Out:
# generator_hiding/g_e1_c/Conv/weights:0
# generator_hiding/g_e1_bn/scale:0
# generator_hiding/g_e1_bn/offset:0
# generator_hiding/g_e2_c/Conv/weights:0
# generator_hiding/g_e2_bn/scale:0
# generator_hiding/g_e2_bn/offset:0
# generator_hiding/g_e3_c/Conv/weights:0
# generator_hiding/g_e3_bn/scale:0
# generator_hiding/g_e3_bn/offset:0
# generator_hiding/g_r1_c1/Conv/weights:0
# generator_hiding/g_r1_bn1/scale:0
# generator_hiding/g_r1_bn1/offset:0
# generator_hiding/g_r1_c2/Conv/weights:0
# generator_hiding/g_r1_bn2/scale:0
# generator_hiding/g_r1_bn2/offset:0
# generator_hiding/g_r2_c1/Conv/weights:0
# generator_hiding/g_r2_bn1/scale:0
# generator_hiding/g_r2_bn1/offset:0
# generator_hiding/g_r2_c2/Conv/weights:0
# generator_hiding/g_r2_bn2/scale:0
# generator_hiding/g_r2_bn2/offset:0
# generator_hiding/g_r3_c1/Conv/weights:0
# generator_hiding/g_r3_bn1/scale:0
# generator_hiding/g_r3_bn1/offset:0
# generator_hiding/g_r3_c2/Conv/weights:0
# generator_hiding/g_r3_bn2/scale:0
# ...

# %%
# !python main.py --phase recon --stegano_dir ./final/stego --recon_dir ./final/recon --gpu 0 --checkpoint_dir ./check/flower
# Out:
# generator_hiding/g_e1_c/Conv/weights:0
# generator_hiding/g_e1_bn/scale:0
# generator_hiding/g_e1_bn/offset:0
# generator_hiding/g_e2_c/Conv/weights:0
# generator_hiding/g_e2_bn/scale:0
# generator_hiding/g_e2_bn/offset:0
# generator_hiding/g_e3_c/Conv/weights:0
# generator_hiding/g_e3_bn/scale:0
# generator_hiding/g_e3_bn/offset:0
# generator_hiding/g_r1_c1/Conv/weights:0
# generator_hiding/g_r1_bn1/scale:0
# generator_hiding/g_r1_bn1/offset:0
# generator_hiding/g_r1_c2/Conv/weights:0
# generator_hiding/g_r1_bn2/scale:0
# generator_hiding/g_r1_bn2/offset:0
# generator_hiding/g_r2_c1/Conv/weights:0
# generator_hiding/g_r2_bn1/scale:0
# generator_hiding/g_r2_bn1/offset:0
# generator_hiding/g_r2_c2/Conv/weights:0
# generator_hiding/g_r2_bn2/scale:0
# generator_hiding/g_r2_bn2/offset:0
# generator_hiding/g_r3_c1/Conv/weights:0
# generator_hiding/g_r3_bn1/scale:0
# generator_hiding/g_r3_bn1/offset:0
# generator_hiding/g_r3_c2/Conv/weights:0
# generator_hiding/g_r3_bn2/scale:0
# ...
